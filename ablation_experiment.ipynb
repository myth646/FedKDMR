# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 0.1 --data_beta 0.5 --temperature 2 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 0.3 --data_beta 0.5 --temperature 2 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 0.7 --data_beta 0.5 --temperature 2 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 1 --data_beta 0.5 --temperature 2 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# temperature

# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 0.5 --data_beta 0.5 --temperature 1 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !python main_fed.py --model resnet20 --dataset cifar100 --algorithm FedKDMR --num_classes 20 --first_stage_bound 50 --iid 0 --noniid_case 5 --KD_alpha 0.5 --data_beta 0.5 --temperature 0.5 --local_bs 64 --bs 256
# Out:
# mean: 500.0
# std: 106.93549457500069
# The file already exists, skip writing.：data/cifar100_100_noniidCase5_beta0.5.json
# num_classes: 20
# block number: 6
# ResNet_cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
